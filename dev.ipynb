# %% [markdown]
# Please submit the following as a Github repo:
#
# 1) Data Extraction and Transformation
#
# One challenge  is correctly reporting international orders when sales are made in different currencies.
# To solve this, we pull reference exchange rate data that can be used to calculate and report international sales in different currencies.
# The European Central Bank provides an API to collect this data, **[documentation can be found here](https://sdw-wsrest.ecb.europa.eu/help/)** - the **data tab** should provide the information needed for the excercise.
#
# **Using python**, write a script that will **pull exchange rate data that can be used for reporting**. For this exercise,
# we are looking for :
# - data for February 9-10, 2023
# - using the Key Euro Area Indicators dataflow.
# Pull data for all daily currencies against the Euro.
#
# Using fake ecommerce data using the **[API documented here](https://fakeapi.platzi.com/en/rest/introduction)** :
# -  pull data for all products in the ‘Shoes’ category.
# - Assuming the data for these products is in USD,
#     - create a new pandas dataframe that includes all of the products
#     - the price in USD,
#     - the price in EUR,
#     - the date of the exchange rate that was used.

# %%
import requests     
import pandas as pd 
import io

# %%
# Building blocks for the URL
protocol =  'https://'
entrypoint = 'sdw-wsrest.ecb.europa.eu/service/' 
resource = 'data'           
flowRef ='EXR'              # Dataflow for exchange rates 
key = 'D..EUR.SP00.A'    # Defining the dimension values: Daily, all currency, to EURO rate, 

# Define the parameters
params = {
    'startPeriod': '2023-02-09',  # Start date of the time series
    'endPeriod': '2023-02-10',     # End of the time series
    #'format': 'csvdata'
}

# %%
# Construct the URL: https://sdw-wsrest.ecb.europa.eu/service/data/EXR/D.USD.EUR.SP00.A
url = protocol + entrypoint + resource + '/'+ flowRef + '/' + key

# Make the HTTP request
response = requests.get(url, params=params, headers={'Accept': 'text/csv'})

# Check if the response returns succesfully with response code 200
print(response)

# Print the full URL
print(response.url)
# Out:
# <Response [200]>
# https://sdw-wsrest.ecb.europa.eu/service/data/EXR/D..EUR.SP00.A?startPeriod=2023-02-09&endPeriod=2023-02-10

# %%
# data to dataframe
df_exrEU = pd.read_csv(io.StringIO(response.text))
print(df_exrEU.columns)
df_exrEU.head()
# Out:
# Index(['KEY', 'FREQ', 'CURRENCY', 'CURRENCY_DENOM', 'EXR_TYPE', 'EXR_SUFFIX',
#        'TIME_PERIOD', 'OBS_VALUE', 'OBS_STATUS', 'OBS_CONF', 'OBS_PRE_BREAK',
#        'OBS_COM', 'TIME_FORMAT', 'BREAKS', 'COLLECTION', 'COMPILING_ORG',
#        'DISS_ORG', 'DOM_SER_IDS', 'PUBL_ECB', 'PUBL_MU', 'PUBL_PUBLIC',
#        'UNIT_INDEX_BASE', 'COMPILATION', 'COVERAGE', 'DECIMALS', 'NAT_TITLE',
#        'SOURCE_AGENCY', 'SOURCE_PUB', 'TITLE', 'TITLE_COMPL', 'UNIT',
#        'UNIT_MULT'],
#       dtype='object')
#                     KEY FREQ CURRENCY CURRENCY_DENOM EXR_TYPE EXR_SUFFIX  \
# 0  EXR.D.AUD.EUR.SP00.A    D      AUD            EUR     SP00          A
# 1  EXR.D.AUD.EUR.SP00.A    D      AUD            EUR     SP00          A
# 2  EXR.D.BGN.EUR.SP00.A    D      BGN            EUR     SP00          A
# 3  EXR.D.BGN.EUR.SP00.A    D      BGN            EUR     SP00          A
# 4  EXR.D.BRL.EUR.SP00.A    D      BRL            EUR     SP00          A
#
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_CONF  ...  COMPILATION  COVERAGE  \
# 0  2023-02-09     1.5409          A        F  ...          NaN       NaN
# 1  2023-02-10     1.5432          A        F  ...          NaN       NaN
# 2  2023-02-09     1.9558          A        F  ...          NaN       NaN
# 3  2023-02-10     1.9558          A        F  ...          NaN       NaN
# 4  2023-02-09     5.6165          A        F  ...          NaN       NaN
#
#   DECIMALS  NAT_TITLE SOURCE_AGENCY  SOURCE_PUB                   TITLE  \
# 0        4        NaN           4F0         NaN  Australian dollar/Euro
# 1        4        NaN           4F0         NaN  Australian dollar/Euro
# 2        4        NaN           4F0         NaN      Bulgarian lev/Euro
# 3        4        NaN           4F0         NaN      Bulgarian lev/Euro
# 4        4        NaN           4F0         NaN     Brazilian real/Euro
#
#                                          TITLE_COMPL  UNIT  UNIT_MULT
# 0  ECB reference exchange rate, Australian dollar...   AUD          0
# 1  ECB reference exchange rate, Australian dollar...   AUD          0
# 2  ECB reference exchange rate, Bulgarian lev/Eur...   BGN          0
# 3  ECB reference exchange rate, Bulgarian lev/Eur...   BGN          0
# 4  ECB reference exchange rate, Brazilian real/Eu...   BRL          0
#
# [5 rows x 32 columns]

# %%
# select columns of interest, rename, lowercase (glue job), reorder for what makes sense to readability of stakeholders, sort by currency
df_exrEU = df_exrEU[['TIME_PERIOD','OBS_VALUE','CURRENCY']]
df_exrEU.rename({'OBS_VALUE':'exr_eur'},inplace=True, axis=1)
df_exrEU.columns= df_exrEU.columns.str.lower()
df_exrEU = df_exrEU[['time_period', 'currency', 'exr_eur']].sort_values('currency')
df_exrEU
# Out:
#    time_period currency      exr_eur
# 0   2023-02-09      AUD      1.54090
# 1   2023-02-10      AUD      1.54320
# 2   2023-02-09      BGN      1.95580
# 3   2023-02-10      BGN      1.95580
# 4   2023-02-09      BRL      5.61650
# 5   2023-02-10      BRL      5.62450
# 6   2023-02-09      CAD      1.44230
# 7   2023-02-10      CAD      1.43640
# 8   2023-02-09      CHF      0.98900
# 9   2023-02-10      CHF      0.98720
# 10  2023-02-09      CNY      7.29920
# 11  2023-02-10      CNY      7.28370
# 13  2023-02-10      CZK     23.69200
# 12  2023-02-09      CZK     23.69800
# 14  2023-02-09      DKK      7.44190
# 15  2023-02-10      DKK      7.44450
# 16  2023-02-09      GBP      0.88515
# 17  2023-02-10      GBP      0.88348
# 18  2023-02-09      HKD      8.45510
# 19  2023-02-10      HKD      8.39160
# 20  2023-02-09      HUF    385.80000
# 21  2023-02-10      HUF    389.78000
# 22  2023-02-09      IDR  16279.95000
# 23  2023-02-10      IDR  16233.33000
# 24  2023-02-09      ILS      3.75760
# 25  2023-02-10      ILS      3.78200
# 26  2023-02-09      INR     88.89050
# 27  2023-02-10      INR     88.24750
# 29  2023-02-10      ISK    152.10000
# 28  2023-02-09      ISK    151.10000
# 30  2023-02-09      JPY    140.80000
# 31  2023-02-10      JPY    139.88000
# 32  2023-02-09      KRW   1355.38000
# 33  2023-02-10      KRW   1354.10000
# 34  2023-02-09      MXN     20.32930
# 35  2023-02-10      MXN     20.05400
# 36  2023-02-09      MYR      4.64880
# 37  2023-02-10      MYR      4.63140
# 38  2023-02-09      NOK     10.91230
# 39  2023-02-10      NOK     10.87100
# 40  2023-02-09      NZD      1.69060
# 41  2023-02-10      NZD      1.69040
# 43  2023-02-10      PHP     58.20700
# 42  2023-02-09      PHP     58.65900
# 45  2023-02-10      PLN      4.78100
# 44  2023-02-09      PLN      4.73880
# 46  2023-02-09      RON      4.89350
# 47  2023-02-10      RON      4.90200
# 48  2023-02-09      SEK     11.13900
# 49  2023-02-10      SEK     11.16300
# 50  2023-02-09      SGD      1.42370
# 51  2023-02-10      SGD      1.41990
# 52  2023-02-09      THB     36.01300
# 53  2023-02-10      THB     36.05700
# 54  2023-02-09      TRY     20.28440
# 55  2023-02-10      TRY     20.13570
# 56  2023-02-09      USD      1.07710
# 57  2023-02-10      USD      1.06900
# 58  2023-02-09      ZAR     19.01340
# 59  2023-02-10      ZAR     19.08340

# %%
### get shoes categoryid

url = "https://api.escuelajs.co/api/v1/categories"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")

### id 4
# Out:
# [{'id': 1, 'name': 'Clothes', 'image': 'https://api.lorem.space/image/fashion?w=640&h=480&r=2813', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}, {'id': 2, 'name': 'ele', 'image': 'https://api.lorem.space/image/watch?w=640&h=480&r=1345', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T13:42:39.000Z'}, {'id': 3, 'name': 'Furniture', 'image': 'https://api.lorem.space/image/furniture?w=640&h=480&r=1249', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}, {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}, {'id': 5, 'name': 'kkkk', 'image': 'https://api.lorem.space/image?w=640&h=480&r=8085', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T14:26:41.000Z'}, {'id': 6, 'name': 'sss', 'image': 'https://th.bing.com/th?id=OIP.GCw9SLDd9mlYzcqPUW8WAAHaJQ&w=223&h=279&c=8&rs=1&qlt=90&o=6&dpr=1.3&pid=3.1&rm=2', 'creationAt': '2023-03-11T08:44:27.000Z', 'updatedAt': '2023-03-11T13:42:31.000Z'}, {'id': 9, 'name': 'jjj', 'image': 'https://firebasestorage.googleapis.com/v0/b/nextproject-f1369.appspot.com/o/files%2Fdes1.jpg?alt=media&token=6a406824-b975-4acc-8e6e-e98ab4110bf9', 'creationAt': '2023-03-11T14:29:52.000Z', 'updatedAt': '2023-03-11T14:41:32.000Z'}, {'id': 10, 'name': 'zfzegf', 'image': 'https://firebasestorage.googleapis.com/v0/b/nextproject-f1369.appspot.com/o/files%2Fbll.jpg?alt=media&token=1ff6b6d8-0421-46dd-a2d6-6559d09488a3', 'creationAt': '2023-03-11T14:41:20.000Z', 'updatedAt': '2023-03-11T14:41:20.000Z'}]

# %%
### get all products by categoryid

url = "https://api.escuelajs.co/api/v1/categories/4/products"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# [{'id': 42, 'title': 'Bespoke Bronze Shirt', 'price': 808, 'description': 'Andy shoes are designed to keeping in mind durability as well as trends, the most stylish range of shoes & sandals', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=6149', 'https://api.lorem.space/image/shoes?w=640&h=480&r=1568', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2424'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 51, 'title': 'asadsasdadasdasd', 'price': 100, 'description': 'The slim & simple Maple Gaming Keyboard from Dev Byte comes with a sleek body and 7- Color RGB LED Back-lighting for smart functionality', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=3589', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2134', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4140'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T14:27:27.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 59, 'title': 'Bespoke Steel Chair', 'price': 256, 'description': 'The Football Is Good For Training And Recreational Purposes', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=5080', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4531', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7201'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 68, 'title': 'Practical Cotton Car', 'price': 54, 'description': 'Ergonomic executive chair upholstered in bonded black leather and PVC padded seat and back for all-day comfort and support', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=1224', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4389', 'https://api.lorem.space/image/shoes?w=640&h=480&r=8721'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 81, 'title': 'Bespoke Rubber Keyboard', 'price': 127, 'description': 'The automobile layout consists of a front-engine design, with transaxle-type transmissions mounted at the rear of the engine and four wheel drive', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=5042', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7892', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7710'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 87, 'title': 'Handmade Granite Salad', 'price': 570, 'description': 'The beautiful range of Apple Naturalé that has an exciting mix of natural ingredients. With the Goodness of 100% Natural Ingredients', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=4671', 'https://api.lorem.space/image/shoes?w=640&h=480&r=6600', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2961'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 90, 'title': 'Incredible Wooden Towels', 'price': 740, 'descrip ...

# %%
# data to dataframe
json_shoes = response.json()
df_shoes = pd.DataFrame(json_shoes)
print(df_shoes.columns)
print(df_shoes.shape)
df_shoes.head()
# Out:
# Index(['id', 'title', 'price', 'description', 'images', 'creationAt',
#        'updatedAt', 'category'],
#       dtype='object')
# (24, 8)
#    id                    title  price  \
# 0  42     Bespoke Bronze Shirt    808
# 1  51         asadsasdadasdasd    100
# 2  59      Bespoke Steel Chair    256
# 3  68     Practical Cotton Car     54
# 4  81  Bespoke Rubber Keyboard    127
#
#                                          description  \
# 0  Andy shoes are designed to keeping in mind dur...
# 1  The slim & simple Maple Gaming Keyboard from D...
# 2  The Football Is Good For Training And Recreati...
# 3  Ergonomic executive chair upholstered in bonde...
# 4  The automobile layout consists of a front-engi...
#
#                                               images  \
# 0  [https://api.lorem.space/image/shoes?w=640&h=4...
# 1  [https://api.lorem.space/image/shoes?w=640&h=4...
# 2  [https://api.lorem.space/image/shoes?w=640&h=4...
# 3  [https://api.lorem.space/image/shoes?w=640&h=4...
# 4  [https://api.lorem.space/image/shoes?w=640&h=4...
#
#                  creationAt                 updatedAt  \
# 0  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
# 1  2023-03-11T05:52:10.000Z  2023-03-11T14:27:27.000Z
# 2  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
# 3  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
# 4  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
#
#                                             category
# 0  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 1  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 2  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 3  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 4  {'id': 4, 'name': 'Shoes', 'image': 'https://a...

# %%
## select cols of df_shoes 
df_shoes = df_shoes[['title','price']]
df_shoes['currency'] = 'USD'
print(df_shoes.columns)
print(df_shoes.shape)
df_shoes.head(100)
# Out:
# Index(['title', 'price', 'currency'], dtype='object')
# (24, 3)
#                        title  price currency
# 0       Bespoke Bronze Shirt    808      USD
# 1           asadsasdadasdasd    100      USD
# 2        Bespoke Steel Chair    256      USD
# 3       Practical Cotton Car     54      USD
# 4    Bespoke Rubber Keyboard    127      USD
# 5     Handmade Granite Salad    570      USD
# 6   Incredible Wooden Towels    740      USD
# 7       Oriental Fresh Shirt    453      USD
# 8       Ergonomic Cotton Car    539      USD
# 9         Elegant Fresh Soap    332      USD
# 10     Licensed Frozen Pizza     54      USD
# 11      Generic Rubber Pants    608      USD
# 12     Generic Plastic Shoes    480      USD
# 13        Generic Fresh Tuna    486      USD
# 14      Awesome Frozen Shoes    650      USD
# 15      Refined Bronze Shoes    864      USD
# 16          Small Wooden Car     94      USD
# 17    Handmade Soft Sausages    520      USD
# 18     Incredible Metal Soap    579      USD
# 19     Ergonomic Metal Mouse    918      USD
# 20     Handmade Bronze Pizza    266      USD
# 21  Bespoke Plastic Keyboard    441      USD
# 22      Luxurious Cotton Car    138      USD
# 23            Bespoke Bronze    123      USD

# %%
## filter df_exrEU by US
df_EUUS = df_exrEU.query('currency == "USD"')
print(df_EUUS.columns)
print(df_EUUS.shape)
df_EUUS
# Out:
# Index(['time_period', 'currency', 'exr_eur'], dtype='object')
# (2, 3)
#    time_period currency  exr_eur
# 56  2023-02-09      USD   1.0771
# 57  2023-02-10      USD   1.0690

# %%
## left join df_shoes to df_EUUS on currency
df_shoes_EUUS =  df_shoes.merge(df_EUUS, on='currency', how='left')
print(df_shoes_EUUS.columns)
print(df_shoes_EUUS.shape)
df_shoes_EUUS
# Out:
# Index(['title', 'price', 'currency', 'time_period', 'exr_eur'], dtype='object')
# (48, 5)
#                        title  price currency time_period  exr_eur
# 0       Bespoke Bronze Shirt    808      USD  2023-02-09   1.0771
# 1       Bespoke Bronze Shirt    808      USD  2023-02-10   1.0690
# 2           asadsasdadasdasd    100      USD  2023-02-09   1.0771
# 3           asadsasdadasdasd    100      USD  2023-02-10   1.0690
# 4        Bespoke Steel Chair    256      USD  2023-02-09   1.0771
# 5        Bespoke Steel Chair    256      USD  2023-02-10   1.0690
# 6       Practical Cotton Car     54      USD  2023-02-09   1.0771
# 7       Practical Cotton Car     54      USD  2023-02-10   1.0690
# 8    Bespoke Rubber Keyboard    127      USD  2023-02-09   1.0771
# 9    Bespoke Rubber Keyboard    127      USD  2023-02-10   1.0690
# 10    Handmade Granite Salad    570      USD  2023-02-09   1.0771
# 11    Handmade Granite Salad    570      USD  2023-02-10   1.0690
# 12  Incredible Wooden Towels    740      USD  2023-02-09   1.0771
# 13  Incredible Wooden Towels    740      USD  2023-02-10   1.0690
# 14      Oriental Fresh Shirt    453      USD  2023-02-09   1.0771
# 15      Oriental Fresh Shirt    453      USD  2023-02-10   1.0690
# 16      Ergonomic Cotton Car    539      USD  2023-02-09   1.0771
# 17      Ergonomic Cotton Car    539      USD  2023-02-10   1.0690
# 18        Elegant Fresh Soap    332      USD  2023-02-09   1.0771
# 19        Elegant Fresh Soap    332      USD  2023-02-10   1.0690
# 20     Licensed Frozen Pizza     54      USD  2023-02-09   1.0771
# 21     Licensed Frozen Pizza     54      USD  2023-02-10   1.0690
# 22      Generic Rubber Pants    608      USD  2023-02-09   1.0771
# 23      Generic Rubber Pants    608      USD  2023-02-10   1.0690
# 24     Generic Plastic Shoes    480      USD  2023-02-09   1.0771
# 25     Generic Plastic Shoes    480      USD  2023-02-10   1.0690
# 26        Generic Fresh Tuna    486      USD  2023-02-09   1.0771
# 27        Generic Fresh Tuna    486      USD  2023-02-10   1.0690
# 28      Awesome Frozen Shoes    650      USD  2023-02-09   1.0771
# 29      Awesome Frozen Shoes    650      USD  2023-02-10   1.0690
# 30      Refined Bronze Shoes    864      USD  2023-02-09   1.0771
# 31      Refined Bronze Shoes    864      USD  2023-02-10   1.0690
# 32          Small Wooden Car     94      USD  2023-02-09   1.0771
# 33          Small Wooden Car     94      USD  2023-02-10   1.0690
# 34    Handmade Soft Sausages    520      USD  2023-02-09   1.0771
# 35    Handmade Soft Sausages    520      USD  2023-02-10   1.0690
# 36     Incredible Metal Soap    579      USD  2023-02-09   1.0771
# 37     Incredible Metal Soap    579      USD  2023-02-10   1.0690
# 38     Ergonomic Metal Mouse    918      USD  2023-02-09   1.0771
# 39     Ergonomic Metal Mouse    918      USD  2023-02-10   1.0690
# 40     Handmade Bronze Pizza    266      USD  2023-02-09   1.0771
# 41     Handmade Bronze Pizza    266      USD  2023-02-10   1.0690
# 42  Bespoke Plastic Keyboard    441      USD  2023-02-09   1.0771
# 43  Bespoke Plastic Keyboard    441      USD  2023-02-10   1.0690
# 44      Luxurious Cotton Car    138      USD  2023-02-09   1.0771
# 45      Luxurious Cotton Car    138      USD  2023-02-10   1.0690
# 46            Bespoke Bronze    123      USD  2023-02-09   1.0771
# 47            Bespoke Bronze    123      USD  2023-02-10   1.0690

# %%
'''
Using fake ecommerce data using the API documented here - 
pull data for all products in the ‘Shoes’ category. 
Assuming the data for these products is in USD, create a new pandas dataframe that includes 
- all of the products, 
- the price in USD, 
- the price in EUR, 
- the date of the exchange rate that was used. 
'''
df_shoes_EUUS['price_EUR'] = round(df_shoes_EUUS['price'] / df_shoes_EUUS['exr_eur'],2)
df_shoes_EUUS.rename({'title':'product_name', 'price':'price_US', 'time_period':'date_exr'}, axis=1, inplace=True) 
df_shoes_EUUS.drop(['exr_eur','currency'], axis=1, inplace=True)
df_shoes_EUUS = df_shoes_EUUS[['product_name', 'price_US', 'price_EUR', 'date_exr']]
df_shoes_EUUS
# Out:
#                 product_name  price_US  price_EUR    date_exr
# 0       Bespoke Bronze Shirt       808     750.16  2023-02-09
# 1       Bespoke Bronze Shirt       808     755.85  2023-02-10
# 2           asadsasdadasdasd       100      92.84  2023-02-09
# 3           asadsasdadasdasd       100      93.55  2023-02-10
# 4        Bespoke Steel Chair       256     237.68  2023-02-09
# 5        Bespoke Steel Chair       256     239.48  2023-02-10
# 6       Practical Cotton Car        54      50.13  2023-02-09
# 7       Practical Cotton Car        54      50.51  2023-02-10
# 8    Bespoke Rubber Keyboard       127     117.91  2023-02-09
# 9    Bespoke Rubber Keyboard       127     118.80  2023-02-10
# 10    Handmade Granite Salad       570     529.20  2023-02-09
# 11    Handmade Granite Salad       570     533.21  2023-02-10
# 12  Incredible Wooden Towels       740     687.03  2023-02-09
# 13  Incredible Wooden Towels       740     692.24  2023-02-10
# 14      Oriental Fresh Shirt       453     420.57  2023-02-09
# 15      Oriental Fresh Shirt       453     423.76  2023-02-10
# 16      Ergonomic Cotton Car       539     500.42  2023-02-09
# 17      Ergonomic Cotton Car       539     504.21  2023-02-10
# 18        Elegant Fresh Soap       332     308.24  2023-02-09
# 19        Elegant Fresh Soap       332     310.57  2023-02-10
# 20     Licensed Frozen Pizza        54      50.13  2023-02-09
# 21     Licensed Frozen Pizza        54      50.51  2023-02-10
# 22      Generic Rubber Pants       608     564.48  2023-02-09
# 23      Generic Rubber Pants       608     568.76  2023-02-10
# 24     Generic Plastic Shoes       480     445.64  2023-02-09
# 25     Generic Plastic Shoes       480     449.02  2023-02-10
# 26        Generic Fresh Tuna       486     451.21  2023-02-09
# 27        Generic Fresh Tuna       486     454.63  2023-02-10
# 28      Awesome Frozen Shoes       650     603.47  2023-02-09
# 29      Awesome Frozen Shoes       650     608.04  2023-02-10
# 30      Refined Bronze Shoes       864     802.15  2023-02-09
# 31      Refined Bronze Shoes       864     808.23  2023-02-10
# 32          Small Wooden Car        94      87.27  2023-02-09
# 33          Small Wooden Car        94      87.93  2023-02-10
# 34    Handmade Soft Sausages       520     482.78  2023-02-09
# 35    Handmade Soft Sausages       520     486.44  2023-02-10
# 36     Incredible Metal Soap       579     537.55  2023-02-09
# 37     Incredible Metal Soap       579     541.63  2023-02-10
# 38     Ergonomic Metal Mouse       918     852.29  2023-02-09
# 39     Ergonomic Metal Mouse       918     858.75  2023-02-10
# 40     Handmade Bronze Pizza       266     246.96  2023-02-09
# 41     Handmade Bronze Pizza       266     248.83  2023-02-10
# 42  Bespoke Plastic Keyboard       441     409.43  2023-02-09
# 43  Bespoke Plastic Keyboard       441     412.54  2023-02-10
# 44      Luxurious Cotton Car       138     128.12  2023-02-09
# 45      Luxurious Cotton Car       138     129.09  2023-02-10
# 46            Bespoke Bronze       123     114.20  2023-02-09
# 47            Bespoke Bronze       123     115.06  2023-02-10

# %%
#### full dev code

# imports
import requests     
import pandas as pd 
import io

################### Connect to EBC API and get exchange rate data
# Building blocks for the URL
protocol =  'https://'
entrypoint = 'sdw-wsrest.ecb.europa.eu/service/' 
resource = 'data'           
flowRef ='EXR'              # Dataflow for exchange rates 
key = 'D..EUR.SP00.A'    # Defining the dimension values: Daily, all currency, to EURO rate 

# Define the parameters
params = {
    'startPeriod': '2023-02-09',
    'endPeriod': '2023-02-10',       
}

# Construct the URL
url = protocol + entrypoint + resource + '/'+ flowRef + '/' + key

# Make the HTTP request
response = requests.get(url, params=params, headers={'Accept': 'text/csv'})

# Check if the response returns succesfully with response code 200
print(response)

# Print the full URL
print(response.url)


# EBC data to dataframe
df_exrEU = pd.read_csv(io.StringIO(response.text))
print(df_exrEU.columns)
print(df_exrEU.shape)
print(df_exrEU.head(3))

# select columns , rename, lowercase (glue job), reorder for what makes sense to readability of stakeholders, sort by currency
df_exrEU = df_exrEU[['TIME_PERIOD','OBS_VALUE','CURRENCY']]
df_exrEU.rename({'OBS_VALUE':'exr_eur'},inplace=True, axis=1)
df_exrEU.columns= df_exrEU.columns.str.lower()
df_exrEU = df_exrEU[['time_period', 'currency', 'exr_eur']].sort_values('currency')
print(df_exrEU.columns)
print(df_exrEU.shape)
print(df_exrEU.head(3))

result1 = df_exrEU

####################  Connect to Fake ecommerce API and get all products by categoryid = 4 (Shoes)

url = "https://api.escuelajs.co/api/v1/categories/4/products"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")

# Fake Ecomm data to dataframe
json_shoes = response.json()
df_shoes = pd.DataFrame(json_shoes)
print(df_shoes.columns)
print(df_shoes.shape)
print(df_shoes.head(3))


## select cols, create currency col for join
df_shoes = df_shoes[['title','price']]
df_shoes['currency'] = 'USD'
print(df_shoes.columns)
print(df_shoes.shape)
print(df_shoes.head(3))

## filtrando df_exrEU por US
df_EUUS = df_exrEU.query('currency == "USD"')
print(df_EUUS.columns)
print(df_EUUS.shape)
print(df_EUUS.head(3))

#################### Fake ecomm data <Left Join> EBC data on currency
# left join
df_shoes_EUUS =  df_shoes.merge(df_EUUS, on='currency', how='left')
print(df_shoes_EUUS.columns)
print(df_shoes_EUUS.shape)
print(df_shoes_EUUS.head(3))

# calculate EUR price, rename cols, drop col, reorganize cols
df_shoes_EUUS['price_EUR'] = round(df_shoes_EUUS['price'] / df_shoes_EUUS['exr_eur'],2)
df_shoes_EUUS.rename({'title':'product_name', 'price':'price_US', 'time_period':'date_exr'}, axis=1, inplace=True) 
df_shoes_EUUS.drop(['exr_eur','currency'], axis=1, inplace=True)
df_shoes_EUUS = df_shoes_EUUS[['product_name', 'price_US', 'price_EUR', 'date_exr']]
print(df_shoes_EUUS.columns)
print(df_shoes_EUUS.shape)
print(df_shoes_EUUS.head(3))

result2 = df_shoes_EUUS

print('EBC EXR data fetch:', result1.head(10))
print('Final result data fetch:', result2.head(10))
# Out:
# <Response [200]>
# https://sdw-wsrest.ecb.europa.eu/service/data/EXR/D..EUR.SP00.A?startPeriod=2023-02-09&endPeriod=2023-02-10
# Index(['KEY', 'FREQ', 'CURRENCY', 'CURRENCY_DENOM', 'EXR_TYPE', 'EXR_SUFFIX',
#        'TIME_PERIOD', 'OBS_VALUE', 'OBS_STATUS', 'OBS_CONF', 'OBS_PRE_BREAK',
#        'OBS_COM', 'TIME_FORMAT', 'BREAKS', 'COLLECTION', 'COMPILING_ORG',
#        'DISS_ORG', 'DOM_SER_IDS', 'PUBL_ECB', 'PUBL_MU', 'PUBL_PUBLIC',
#        'UNIT_INDEX_BASE', 'COMPILATION', 'COVERAGE', 'DECIMALS', 'NAT_TITLE',
#        'SOURCE_AGENCY', 'SOURCE_PUB', 'TITLE', 'TITLE_COMPL', 'UNIT',
#        'UNIT_MULT'],
#       dtype='object')
# (60, 32)
#                     KEY FREQ CURRENCY CURRENCY_DENOM EXR_TYPE EXR_SUFFIX  \
# 0  EXR.D.AUD.EUR.SP00.A    D      AUD            EUR     SP00          A
# 1  EXR.D.AUD.EUR.SP00.A    D      AUD            EUR     SP00          A
# 2  EXR.D.BGN.EUR.SP00.A    D      BGN            EUR     SP00          A
#
#   TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_CONF  ...  COMPILATION  COVERAGE  \
# 0  2023-02-09     1.5409          A        F  ...          NaN       NaN
# 1  2023-02-10     1.5432          A        F  ...          NaN       NaN
# 2  2023-02-09     1.9558          A        F  ...          NaN       NaN
#
#   DECIMALS  NAT_TITLE SOURCE_AGENCY  SOURCE_PUB                   TITLE  \
# 0        4        NaN           4F0         NaN  Australian dollar/Euro
# 1        4        NaN           4F0         NaN  Australian dollar/Euro
# 2        4        NaN           4F0         NaN      Bulgarian lev/Euro
#
#                                          TITLE_COMPL  UNIT  UNIT_MULT
# 0  ECB reference exchange rate, Australian dollar...   AUD          0
# 1  ECB reference exchange rate, Australian dollar...   AUD          0
# 2  ECB reference exchange rate, Bulgarian lev/Eur...   BGN          0
#
# [3 rows x 32 columns]
# Index(['time_period', 'currency', 'exr_eur'], dtype='object')
# (60, 3)
#   time_period currency  exr_eur
# 0  2023-02-09      AUD   1.5409
# 1  2023-02-10      AUD   1.5432
# 2  2023-02-09      BGN   1.9558
# [{'id': 42, 'title': 'Bespoke Bronze Shirt', 'price': 808, 'description': 'Andy shoes are designed to keeping in mind durability as well as trends, the most stylish range of shoes & sandals', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=6149', 'https://api.lorem.space/image/shoes?w=640&h=480&r=1568', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2424'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 51, 'title': 'asadsasdadasdasd', 'price': 100, 'description': 'The slim & simple Maple Gaming Keyboard from Dev Byte comes with a sleek body and 7- Color RGB LED Back-lighting for smart functionality', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=3589', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2134', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4140'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T14:27:27.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 59, 'title': 'Bespoke Steel Chair', 'price': 256, 'description': 'The Football Is Good For Training And Recreational Purposes', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=5080', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4531', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7201'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 68, 'title': 'Practical Cotton Car', 'price': 54, 'description': 'Ergonomic executive chair upholstered in bonded black leather and PVC padded seat and back for all-day comfort and support', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=1224', 'https://api.lorem.space/image/shoes?w=640&h=480&r=4389', 'https://api.lorem.space/image/shoes?w=640&h=480&r=8721'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 81, 'title': 'Bespoke Rubber Keyboard', 'price': 127, 'description': 'The automobile layout consists of a front-engine design, with transaxle-type transmissions mounted at the rear of the engine and four wheel drive', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=5042', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7892', 'https://api.lorem.space/image/shoes?w=640&h=480&r=7710'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 87, 'title': 'Handmade Granite Salad', 'price': 570, 'description': 'The beautiful range of Apple Naturalé that has an exciting mix of natural ingredients. With the Goodness of 100% Natural Ingredients', 'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=4671', 'https://api.lorem.space/image/shoes?w=640&h=480&r=6600', 'https://api.lorem.space/image/shoes?w=640&h=480&r=2961'], 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z', 'category': {'id': 4, 'name': 'Shoes', 'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=6370', 'creationAt': '2023-03-11T05:52:10.000Z', 'updatedAt': '2023-03-11T05:52:10.000Z'}}, {'id': 90, 'title': 'Incredible Wooden Towels', 'price': 740, 'descrip ...
# Index(['id', 'title', 'price', 'description', 'images', 'creationAt',
#        'updatedAt', 'category'],
#       dtype='object')
# (24, 8)
#    id                 title  price  \
# 0  42  Bespoke Bronze Shirt    808
# 1  51      asadsasdadasdasd    100
# 2  59   Bespoke Steel Chair    256
#
#                                          description  \
# 0  Andy shoes are designed to keeping in mind dur...
# 1  The slim & simple Maple Gaming Keyboard from D...
# 2  The Football Is Good For Training And Recreati...
#
#                                               images  \
# 0  [https://api.lorem.space/image/shoes?w=640&h=4...
# 1  [https://api.lorem.space/image/shoes?w=640&h=4...
# 2  [https://api.lorem.space/image/shoes?w=640&h=4...
#
#                  creationAt                 updatedAt  \
# 0  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
# 1  2023-03-11T05:52:10.000Z  2023-03-11T14:27:27.000Z
# 2  2023-03-11T05:52:10.000Z  2023-03-11T05:52:10.000Z
#
#                                             category
# 0  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 1  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# 2  {'id': 4, 'name': 'Shoes', 'image': 'https://a...
# Index(['title', 'price', 'currency'], dtype='object')
# (24, 3)
#                   title  price currency
# 0  Bespoke Bronze Shirt    808      USD
# 1      asadsasdadasdasd    100      USD
# 2   Bespoke Steel Chair    256      USD
# Index(['time_period', 'currency', 'exr_eur'], dtype='object')
# (2, 3)
#    time_period currency  exr_eur
# 56  2023-02-09      USD   1.0771
# 57  2023-02-10      USD   1.0690
# Index(['title', 'price', 'currency', 'time_period', 'exr_eur'], dtype='object')
# (48, 5)
#                   title  price currency time_period  exr_eur
# 0  Bespoke Bronze Shirt    808      USD  2023-02-09   1.0771
# 1  Bespoke Bronze Shirt    808      USD  2023-02-10   1.0690
# 2      asadsasdadasdasd    100      USD  2023-02-09   1.0771
# Index(['product_name', 'price_US', 'price_EUR', 'date_exr'], dtype='object')
# (48, 4)
#            product_name  price_US  price_EUR    date_exr
# 0  Bespoke Bronze Shirt       808     750.16  2023-02-09
# 1  Bespoke Bronze Shirt       808     755.85  2023-02-10
# 2      asadsasdadasdasd       100      92.84  2023-02-09
# EBC EXR data fetch:   time_period currency  exr_eur
# 0  2023-02-09      AUD   1.5409
# 1  2023-02-10      AUD   1.5432
# 2  2023-02-09      BGN   1.9558
# 3  2023-02-10      BGN   1.9558
# 4  2023-02-09      BRL   5.6165
# 5  2023-02-10      BRL   5.6245
# 6  2023-02-09      CAD   1.4423
# 7  2023-02-10      CAD   1.4364
# 8  2023-02-09      CHF   0.9890
# 9  2023-02-10      CHF   0.9872
# Final result data fetch:               product_name  price_US  price_EUR    date_exr
# 0     Bespoke Bronze Shirt       808     750.16  2023-02-09
# 1     Bespoke Bronze Shirt       808     755.85  2023-02-10
# 2         asadsasdadasdasd       100      92.84  2023-02-09
# 3         asadsasdadasdasd       100      93.55  2023-02-10
# 4      Bespoke Steel Chair       256     237.68  2023-02-09
# 5      Bespoke Steel Chair       256     239.48  2023-02-10
# 6     Practical Cotton Car        54      50.13  2023-02-09
# 7     Practical Cotton Car        54      50.51  2023-02-10
# 8  Bespoke Rubber Keyboard       127     117.91  2023-02-09
# 9  Bespoke Rubber Keyboard       127     118.80  2023-02-10
